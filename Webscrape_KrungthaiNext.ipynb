# %% [markdown]
# Step 0: Install required packages

# %%
# !pip install -q google_play_scraper #Scraping review
# !pip install -q transformers #Sentiment
# !pip install -q plotly-express #Data Visualization
# !pip install pyyaml==5.4.1 #Required package for plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Step 1: Import packages

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, Sort, reviews
import plotly.express as px

# %% [markdown]
# Step 2: Get the ID of the Google Play app from the URL

# %%
result, continuation_token = reviews('ktbcs.netbank', lang ='th',country='TH', sort=Sort.NEWEST, count=1000)

# %% [markdown]
# Step 3: Normalize the nested json

# %%
result
# Out:
# [{'reviewId': 'bdfd375a-701e-4bc4-a5ff-ac1405a4f063',
#   'userName': 'สุริยา ณ.สมุทร',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ACNPEu8UgdRLHG80hp_OTsUl7qLMqbP1TjNh8glJfy2aPQ',
#   'content': 'ดี',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.9.1',
#   'at': datetime.datetime(2022, 11, 12, 7, 17, 54),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '9181b9cf-bc01-4b90-bc65-aa67ae5ebb81',
#   'userName': 'Jumlean Luecha',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ALm5wu3cDMjBvxGSygqE5dGWofpuR-tgNp_WbWZgFgFc=mo',
#   'content': 'Good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '11.9.1',
#   'at': datetime.datetime(2022, 11, 12, 6, 53, 18),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'f14a5783-0f0f-4c1c-b9d4-7ea0d78f52cf',
#   'userName': 'SAMLEE TRUDMAKKA',
# ...

# %%
app_infos_df = pd.DataFrame(result)
app_infos_df.head()
# Out:
#                                reviewId            userName  \
# 0  bdfd375a-701e-4bc4-a5ff-ac1405a4f063      สุริยา ณ.สมุทร
# 1  9181b9cf-bc01-4b90-bc65-aa67ae5ebb81      Jumlean Luecha
# 2  f14a5783-0f0f-4c1c-b9d4-7ea0d78f52cf    SAMLEE TRUDMAKKA
# 3  3ad1db88-f0c1-4e0f-8853-92352f070acc  มาหามะรอมือลี เห็ง
# 4  377056d6-8f26-4ca0-9695-74eb76e7ed7f         pranee 7232
#
#                                            userImage                  content  \
# 0  https://play-lh.googleusercontent.com/a-/ACNPE...                       ดี
# 1  https://play-lh.googleusercontent.com/a/ALm5wu...                     Good
# 2  https://play-lh.googleusercontent.com/a/ALm5wu...  ให้บริการดีขอบคุณมากค่ะ
# 3  https://play-lh.googleusercontent.com/a/ALm5wu...                     รุ่.
# 4  https://play-lh.googleusercontent.com/a-/ACNPE...   โดยรวมคือดีประทับใจค่ะ
#
#    score  thumbsUpCount reviewCreatedVersion                  at replyContent  \
# ...

# %%
app_infos_df.to_csv('krungthai-next_app.csv', index=None, header=True)
