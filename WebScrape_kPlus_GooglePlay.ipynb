# %% [markdown]
# ref: https://www.linkedin.com/pulse/scrape-google-play-reviews-run-sentiment-analysis-using-kundi/
#
# library document: https://pypi.org/project/google-play-scraper/

# %% [markdown]
# Step 0: Install required packages

# %%
# !pip install -q google_play_scraper #Scraping review

# %% [markdown]
# Step 1: Import packages

# %%
import pandas as pd
from google_play_scraper import app, Sort, reviews

# %% [markdown]
# Step 2: Get the ID of the Google Play app from the URL

# %% [markdown]
# ![Screen Shot 2565-11-08 at 12.44.55.png](data:image/png;base64,...)

# %%
result, continuation_token = reviews('com.kasikorn.retail.mbanking.wap', lang ='th',country='TH', sort=Sort.NEWEST, count=1500)

# %% [markdown]
# Step 3: Normalize the nested json

# %%
result
# Out:
# [{'reviewId': 'd1bc6eb2-ec04-4b70-b5a4-aabfddff750a',
#   'userName': 'นิพนธ์ คําไม',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AEdFTp4t-2eIjxqp-PCewvtkugBTcZ6RD2iSAXgG_1az=mo',
#   'content': 'สะดวกสบายเร็วทันใจ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '5.16.4',
#   'at': datetime.datetime(2022, 12, 13, 17, 8),
#   'replyContent': 'ขอขอบคุณ นิพนธ์ คําไมที่ไว้วางใจใช้บริการ K PLUS ของธนาคารกสิกรไทยค่ะ^^',
#   'repliedAt': datetime.datetime(2022, 12, 14, 4, 27, 38)},
#  {'reviewId': 'cfbb25de-d125-46e3-9786-292acd591d8a',
#   'userName': 'อุทิศ ปุณริบูรณ์',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD5-WClKAEokEZiQEOLPFxBqbtyJ3fvBdxrumluOOzod',
#   'content': 'ดีมากคับ',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 12, 13, 16, 23, 9),
#   'replyContent': 'ขอขอบคุณที่ไว้วางใจใช้บริการ K PLUS ของธนาคารกสิกรไทยค่ะ😊',
# ...

# %%
app_infos_df = pd.DataFrame(result)
app_infos_df.head()
# Out:
#                                reviewId           userName  \
# 0  d1bc6eb2-ec04-4b70-b5a4-aabfddff750a       นิพนธ์ คําไม
# 1  cfbb25de-d125-46e3-9786-292acd591d8a   อุทิศ ปุณริบูรณ์
# 2  4e62a042-cd79-4ff2-8d0f-3ae2cfd51b17  Kitsada Pimmeelay
# 3  efcb1368-ec3c-42fe-b0b6-c35bc7b7b3c8     วริศรา วงเรือน
# 4  5d891fc8-1122-43f8-b4cd-13cad3451ed4   ชูชาติ ภิไชยวงค์
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AEdFTp...
# 1  https://play-lh.googleusercontent.com/a-/AD5-W...
# 2  https://play-lh.googleusercontent.com/a/AEdFTp...
# 3  https://play-lh.googleusercontent.com/a-/AD5-W...
# 4  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                          content  score  thumbsUpCount  \
# 0                             สะดวกสบายเร็วทันใจ      5              0
# 1                                       ดีมากคับ      5              0
# ...

# %%
app_infos_df.to_csv('apps.csv', index=None, header=True)
